# %% [markdown]
# # 1. Student Information

# %%
Name = "Ahmed Raza"

# %%
age = 28

# %%
city = "karachi"

# %%
student_status = "matric class"

# %%
print(Name)
# Out:
# Ahmed Raza

# %%
print (age)
# Out:
# 28

# %%
print(city)
# Out:
# karachi

# %%
print(student_status)
# Out:
# matric class

# %% [markdown]
# # 2. Data Types

# %%
a = "raza" #str

# %%
b = 28 #int

# %%
c = 11.03 #float

# %%
d = (1<2) #bool

# %%
print (a)
# Out:
# raza

# %%
print (b)
# Out:
# 28

# %%
print (c)
# Out:
# 11.03

# %%
print (d)
# Out:
# True

# %%
type (a)
# Out:
# str

# %%
type (b)
# Out:
# int

# %%
type (c)
# Out:
# float

# %%
type (d)
# Out:
# bool

# %% [markdown]
# # 3. Arithmetic Operations

# %%
x = 5
y = 10

# %%
print(x+y)
# Out:
# 15

# %%
print(x-y)
# Out:
# -5

# %%
print(x*y)
# Out:
# 50

# %%
print(x/y)
# Out:
# 0.5

# %%
print(x//y)
# Out:
# 0

# %%
print(x**y)
# Out:
# 9765625

# %%
print(x%y)
# Out:
# 5

# %% [markdown]
# # 4. Student Marks Calculator

# %%
english_subject_marks = 80
maths_subject_marks = 85
urdu_subject_marks = 75

# %%
total_marks_of_student=english_subject_marks+maths_subject_marks+urdu_subject_marks

# %%
print (total_marks_of_student)
# Out:
# 240

# %%
average_marks_of_students=(english_subject_marks+maths_subject_marks+urdu_subject_marks)/3

# %%
print (average_marks_of_students)
# Out:
# 80.0

# %% [markdown]
# # 5. Shopping Bill

# %%
product_price=15
product_qty=1
print (product_price*product_qty)
# Out:
# 15

# %% [markdown]
# # 6. Rectangle Area

# %%
rectangle_length = 8
rectangle_width = 4
area=rectangle_length*rectangle_width
perimeter=2*(rectangle_length+rectangle_width)

# %%
print (area)
# Out:
# 32

# %%
print (perimeter)
# Out:
# 24

# %% [markdown]
# # 7. Time Converter

# %%
time=250 #minutes

# %%
print (time/60)
# Out:
# 4.166666666666667

# %% [markdown]
# # 8. Student Eligibility

# %%
marks=int(input ('enter your marks:'))
attendance=int(input ('enter your attendance:'))
isEligible= (marks>=50) or (attendance >=75)
print (f'marks:{marks}and attendance:{attendance},means student is eligible:{isEligible}')
# Out:
# enter your marks: 15
# enter your attendance: 15
# marks:15and attendance:15,means student is eligible:False

# %% [markdown]
# # 9. Logical Operators

# %% [markdown]
# ## two Boolean variables:

# %%
a=(20>10)

# %%
b=(10>20)

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %% [markdown]
# # Final Challenge Student Report

# %%
student_name ="Muhammad Ahmed Raza"
age=28
english_marks=int(input("Enter Student's English marks"))
urdu_marks=int(input("Enter Student's Urdu  marks"))
maths_marks=int(input("Enter Student's Maths marks"))
average_marks=(english_marks+urdu_marks+maths_marks)//3
attendance=int(input("Enter your Attendance"))
isEligible=(average_marks>=50) and (attendance>=75)
# Out:
# Enter Student's English marks 55
# Enter Student's Urdu  marks 60
# Enter Student's Maths marks 65
# Enter your Attendance 50

# %%
print (f'''Name:- {student_name},
Age: {age},
English: {english_marks},
Urdu: {urdu_marks},
Maths: {maths_marks},
Total_marks: {english_marks+urdu_marks+maths_marks},
Averagemarks: {average_marks},
Attendance: {attendance},
It Means Student Is Eligible:{isEligible}.''')
# Out:
# Name:- Muhammad Ahmed Raza,
# Age: 28,
# English: 55,
# Urdu: 60,
# Maths: 65,
# Total_marks: 180,
# Averagemarks: 60,
# Attendance: 50,
# It Means Student Is Eligible:False.
